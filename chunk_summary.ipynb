# %%
import json
from gliner import GLiNER
import torch
from transformers import BartForConditionalGeneration, BartTokenizerFast

# %%
# Load the model and tokenizer
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
tokenizer = BartTokenizerFast.from_pretrained("facebook/bart-large", tensor_type=torch.uint8)

# Move model to MPS
device = torch.device('mps')
model = model.to(device)

# %%
chunks_filepath = './chunks/wheel_of_time/semantic_chunks/1_12.json'

with open(chunks_filepath, 'r') as f:
    chunks = json.load(f)

# Function to summarize text using BART
def summarize_text(text, max_length=130, min_length=30, length_penalty=2.0, num_beams=4):
    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs, max_length=max_length, min_length=min_length, length_penalty=length_penalty, num_beams=num_beams, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# Summarize each chunk in chunks
summaries = [summarize_text(chunk) for chunk in chunks]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 14
#      11     return summary
#      13 # Summarize each chunk in chunks
# ---> 14 summaries = [summarize_text(chunk) for chunk in chunks]
#
# Cell In[3], line 14, in <listcomp>(.0)
#      11     return summary
#      13 # Summarize each chunk in chunks
# ---> 14 summaries = [summarize_text(chunk) for chunk in chunks]
#
# Cell In[3], line 9, in summarize_text(text, max_length, min_length, length_penalty, num_beams)
#       7 def summarize_text(text, max_length=130, min_length=30, length_penalty=2.0, num_beams=4):
#       8     inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=1024, truncation=True)
# ----> 9     summary_ids = model.generate(inputs, max_length=max_length, min_length=min_length, length_penalty=length_penalty, num_beams=num_beams, early_stopping=True)
# ...

# %%
for chunk, summary in zip(chunks, summaries):
    print(f'{chunk}\n\n{summary}\n-------------------------\n')
# Out:
# CHAPTER 12 Across the Taren Lan came down the stairs, telling the company to dismount and lead their horses after him through the fog. Again they had to trust that the Warder knew where he was going. The fog swirled around Rand's knees, hiding his feet, obscuring everything more than a yard away. The fog was not as heavy as it had been outside the town, but he could barely make out his companions. Still no human stirred in the night except for them.
#
# Rand awoke to the sound of his horse's hooves on the floor of the Warder's house in the middle of the night, and looked around for his companions.
# -------------------------
#
# ...
